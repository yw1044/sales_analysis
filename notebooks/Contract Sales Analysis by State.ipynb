# %%
import pandas as pd
pd.__version__
# Out:
# '1.1.3'

# %%
contracts_df = pd.read_csv('../data/contracts.csv')
contracts_df
# Out:
#      contract_id  customer_id contract_start  contract_term      deposit  \
# 0              1          127      8/17/2019             12  $53,000.00
# 1              2          119      12/1/2019             22  $77,000.00
# 2              3          160       5/1/2019             15  $13,000.00
# 3              4            7      12/8/2019             23  $56,000.00
# 4              5          144      2/11/2019              7  $21,000.00
# ..           ...          ...            ...            ...          ...
# 995          996           57      11/8/2019             15  $38,000.00
# 996          997          126      1/13/2019             20  $28,000.00
# 997          998           89       5/8/2019              7  $73,000.00
# 998          999           52      3/26/2019              7  $63,000.00
# 999         1000            3      3/19/2019             16  $23,000.00
#
#      monthly_amt
# 0    $11,600.00
# 1    $14,600.00
# 2    $22,800.00
# 3    $11,400.00
# ...

# %%
customers_df = pd.read_csv('../data/customers.csv')
customers_df
# Out:
#       id       company            sector  \
# 0      1     Bubblebox     Capital Goods
# 1      2          Izio            Energy
# 2      3  Twitterworks               NaN
# 3      4          Viva       Health Care
# 4      5   Jabberstorm        Technology
# ..   ...           ...               ...
# 245  246      Livefish            Energy
# 246  247          Katz               NaN
# 247  248         Yombu  Public Utilities
# 248  249       Dynazzy               NaN
# 249  250   Twitterwire        Technology
#
#                                     industry                      email  \
# 0              Military/Government/Technical   kyerson0@bizjournals.com
# 1                       Oil & Gas Production        farlet1@comcast.net
# 2                                        NaN         alerohan2@ox.ac.uk
# 3                      Major Pharmaceuticals   wgiovanitti3@nytimes.com
# 4    Computer Software: Prepackaged Software          pscallon4@fc2.com
# ...

# %%
join_df = pd.merge(contracts_df, customers_df, left_on='customer_id', right_on='id')
join_df
# Out:
#      contract_id  customer_id contract_start  contract_term      deposit  \
# 0              1          127      8/17/2019             12  $53,000.00
# 1             27          127       2/5/2019             20  $86,000.00
# 2            112          127      7/15/2019              5  $68,000.00
# 3            296          127      8/13/2019              8  $68,000.00
# 4            498          127      5/21/2019             22  $39,000.00
# ..           ...          ...            ...            ...          ...
# 995          747          136       6/6/2019              9  $93,000.00
# 996          868          136      5/16/2019              6  $22,000.00
# 997          781          149      1/10/2019              2  $92,000.00
# 998          922          149       7/7/2019             14  $24,000.00
# 999          920          159      1/14/2019              3  $26,000.00
#
#      monthly_amt   id  company       sector  \
# 0    $11,600.00   127     Lazz  Health Care
# ...

# %%
join_df['deposit'] = join_df['deposit'].str.replace('$', '')
join_df['deposit'] = join_df['deposit'].str.replace(',', '').astype(float)

join_df['monthly_amt'] = join_df['monthly_amt'].str.replace('$', '')
join_df['monthly_amt'] = join_df['monthly_amt'].str.replace(',', '').astype(float)

join_df
# Out:
#      contract_id  customer_id contract_start  contract_term  deposit  \
# 0              1          127      8/17/2019             12  53000.0
# 1             27          127       2/5/2019             20  86000.0
# 2            112          127      7/15/2019              5  68000.0
# 3            296          127      8/13/2019              8  68000.0
# 4            498          127      5/21/2019             22  39000.0
# ..           ...          ...            ...            ...      ...
# 995          747          136       6/6/2019              9  93000.0
# 996          868          136      5/16/2019              6  22000.0
# 997          781          149      1/10/2019              2  92000.0
# 998          922          149       7/7/2019             14  24000.0
# 999          920          159      1/14/2019              3  26000.0
#
#      monthly_amt   id  company       sector  \
# 0        11600.0  127     Lazz  Health Care
# 1        16300.0  127     Lazz  Health Care
# ...

# %%
join_df['sale'] = pd.Series(join_df['deposit']+join_df['monthly_amt']*join_df['contract_term'])
join_df
# Out:
#      contract_id  customer_id contract_start  contract_term  deposit  \
# 0              1          127      8/17/2019             12  53000.0
# 1             27          127       2/5/2019             20  86000.0
# 2            112          127      7/15/2019              5  68000.0
# 3            296          127      8/13/2019              8  68000.0
# 4            498          127      5/21/2019             22  39000.0
# ..           ...          ...            ...            ...      ...
# 995          747          136       6/6/2019              9  93000.0
# 996          868          136      5/16/2019              6  22000.0
# 997          781          149      1/10/2019              2  92000.0
# 998          922          149       7/7/2019             14  24000.0
# 999          920          159      1/14/2019              3  26000.0
#
#      monthly_amt   id  company       sector  \
# 0        11600.0  127     Lazz  Health Care
# 1        16300.0  127     Lazz  Health Care
# ...

# %%
join_df.groupby('state').agg({'sale': 'sum'})
# Out:
#              sale
# state
# AK      2111900.0
# AL      1896400.0
# AR       293200.0
# AZ      5670700.0
# CA     22211000.0
# CO      7177800.0
# CT      1985300.0
# DC      7297200.0
# DE      3802100.0
# FL     17522100.0
# GA      3064200.0
# ID      3768100.0
# IL      4983600.0
# IN      2302400.0
# KS     10708400.0
# KY      3007800.0
# LA      8083500.0
# MA      1619200.0
# MD      3625700.0
# ME      1385500.0
# MI      4980400.0
# MN      4505300.0
# MO      5456800.0
# MS      1407900.0
# NC      5900800.0
# NE      5474200.0
# NV      1776000.0
# NY      9627400.0
# OH      7365500.0
# OK      7291100.0
# OR      5813700.0
# PA      9068000.0
# SC      1111500.0
# TN      4170700.0
# TX     24602200.0
# VA      7899500.0
# WA     13123600.0
# WI      4621000.0
# WV      1220300.0
